# %%
print("Hello joe")
# Out:
# Hello joe

# %%
2 + 15
# Out:
# 17

# %% [markdown]
# Hello

# %%
import sqlite3
import pandas as pd
# import pprint

conn = sqlite3.connect('sql_run.db')
cursor = conn.cursor()
if cursor: 
    print("Opened database successfully")

data_table = pd.read_sql_query("SELECT * FROM au_orders", conn)

conn.commit()
conn.close()

# pprint.pprint(data_table)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-d4418d6899a1> in <module>
#       1 import sqlite3
# ----> 2 import pandas as pd
#       3 # import pprint
#       4
#       5 conn = sqlite3.connect('sql_run.db')
#
# ModuleNotFoundError: No module named 'pandas'
